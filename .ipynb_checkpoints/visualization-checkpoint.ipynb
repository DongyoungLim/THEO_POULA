# %%
import os
import numpy as np
import pandas as pd
import pickle as pkl
import matplotlib.pyplot as plt
import torch 
import matplotlib.pyplot as plt
pd.options.display.max_columns = 100
model = 'vgg11'


#logs = os.listdir(path)

best_loss ={}
dfs = {}
params = {'axes.labelsize': 20,
          'axes.titlesize': 30,
         }
plt.rcParams.update(params)

# %%
def get_agg_data(names, curve_type='train', model='vgg11', dataset='cifar10'):
    folder_path = './logs/{}/{}'.format(dataset, model)
    paths = [os.path.join(folder_path, name) for name in names]  
    curves = {name: torch.load(fp) for name, fp in zip(names, paths)}#get_data(names[opt])  
    df_agg = pd.DataFrame({ key : value[curve_type +'_acc'] for key, value in curves.items()})
    return df_agg

def agg_plot(names, curve_type='train', model='vgg11', labels = None, ylim=(80,101), loc = 'upper left', figsize=(10,8), dataset='cifar10'):
    plt.figure(figsize=figsize)
    plt.ylim(ylim)
    opts = [label.lower() for label in labels]
  
    for opt, label in zip(opts, labels):
   
        df_agg = get_agg_data(names[opt], curve_type, model, dataset=dataset)
    
        
    
        acc = np.array(df_agg.mean(axis=1))
        std = np.array(df_agg.std(axis=1))    
        x = range(1, len(acc)+1)
        if 'theopoula' in label.lower():
            plt.plot(x, acc, '-', label=label, linewidth=2)
        else: 
            plt.plot(x, acc, '--', label=label, linewidth=2)
        plt.fill_between(x, acc-std, acc+std, alpha=0.15)
  
    plt.legend(fontsize=25, loc=loc)
    plt.grid()
    plt.title('{} ACCURACY'.format(curve_type.upper()))
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.xticks(fontsize =20)
    plt.yticks(fontsize =20)
    plt.tight_layout()
    plt.show()

def get_best_acc(names, curve_type='train', model='vgg11', labels = None, dataset='cifar10'):  
    opts = [label.lower() for label in labels]
  
    for opt, label in zip(opts, labels):
        df_agg = get_agg_data(names[opt], curve_type, model, dataset)
        print(opt, df_agg.max(axis=0).mean(), df_agg.max(axis=0).std())

# %% [markdown]
# ### **VGG11**

# %%
names = {'adam':['vgg_bn-adam-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'vgg_bn-adam-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'vgg_bn-adam-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',             
          ],
         'amsgrad':['vgg_bn-amsgrad-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'vgg_bn-amsgrad-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'vgg_bn-amsgrad-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                                                    
             
         ],
         'rmsprop':['vgg_bn-rmsprop-seed111-lr0.001-wdecay0.0005-run0-resetFalse',
                    'vgg_bn-rmsprop-seed222-lr0.001-wdecay0.0005-run0-resetFalse',
                    'vgg_bn-rmsprop-seed333-lr0.001-wdecay0.0005-run0-resetFalse',
         ],
         'theopoula$^\dagger$':['cifar10-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',                                   
         ],
         'theopoula$^*$':['vgg_bn-theopoula-seed111-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'vgg_bn-theopoula-seed222-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'vgg_bn-theopoula-seed333-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
         ],
         'sgd':['vgg_bn-sgd-seed111-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'vgg_bn-sgd-seed222-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'vgg_bn-sgd-seed333-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',                
         ],
         'adabound':['vgg_bn-adabound-seed111-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'vgg_bn-adabound-seed222-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'vgg_bn-adabound-seed333-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',                 
         ],
         'adabelief':['vgg_bn-adabelief-seed111-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'vgg_bn-adabelief-seed222-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'vgg_bn-adabelief-seed333-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',                               
                     ],
         'adamp':['vgg_bn-adamp-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                  
                      'vgg_bn-adamp-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                      'vgg_bn-adamp-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                               
                     ],
         'tuslac': ['vgg_bn-tuslac-seed111-lr0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse'],         
        }
labels = ['TheoPouLa$^\dagger$', 
          'TheoPouLa$^*$',          
          'Adam',
          'AdaBelief',          
          'AdamP',  
          'AdaBound',
          'Amsgrad',          
          'Rmsprop', 
          'SGD',          
         ]
model = 'vgg11'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (84, 92.5)) 
get_best_acc(names, curve_type='test', model=model, labels=labels)
# Out:
# theopoula$^\dagger$ 92.30666666666667 0.055075705472860816
# theopoula$^*$ 91.91666666666667 0.11930353445449042
# adam 90.79333333333334 0.07505553499464872
# adabelief 92.16666666666667 0.03511884584284627
# adamp 91.67666666666668 0.16258331197676265
# adabound 91.81 0.27184554438136477
# amsgrad 91.24000000000001 0.11532562594670967
# rmsprop 90.81666666666668 0.20108041509140936
# sgd 90.73333333333333 0.09018499505645412

# %% [markdown]
# ### RESNET

# %%
names = {'adam':['resnet-adam-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'resnet-adam-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'resnet-adam-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                
          ],
         'amsgrad':['resnet-amsgrad-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'resnet-amsgrad-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'resnet-amsgrad-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                                
         ],
         'rmsprop':['resnet-rmsprop-seed111-lr0.001-wdecay0.0005-run0-resetFalse',
                    'resnet-rmsprop-seed222-lr0.001-wdecay0.0005-run0-resetFalse',
                    'resnet-rmsprop-seed333-lr0.001-wdecay0.0005-run0-resetFalse',             
         ],
         'theopoula$^\dagger$':['resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                
                      'resnet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'resnet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
         ],
        'theopoula$^*$':['resnet-theopoula-seed111-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'resnet-theopoula-seed222-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'resnet-theopoula-seed333-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
         ],
         'sgd':['resnet-sgd-seed111-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'resnet-sgd-seed222-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'resnet-sgd-seed333-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',               
         ],
         'adabound':['resnet-adabound-seed111-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'resnet-adabound-seed222-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'resnet-adabound-seed333-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',                
         ],
         'adabelief':['resnet-adabelief-seed111-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'resnet-adabelief-seed222-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'resnet-adabelief-seed333-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',                              
                     ],
         'adamp':['resnet-adamp-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                  
                      'resnet-adamp-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                      'resnet-adamp-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',             
                     ],         
        }
labels = ['TheoPouLa$^\dagger$', 
          'TheoPouLa$^*$',           
          'Adam',          
          'AdaBelief',          
          'AdamP',
          'AdaBound',
          'Amsgrad',          
          'Rmsprop',                    
          'SGD',                    
         ]
model = 'resnet34'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (88,96)) 
get_best_acc(names, curve_type='test', model=model, labels=labels)
# Out:
# theopoula$^\dagger$ 95.42999999999999 0.09539392014169346
# theopoula$^*$ 94.91666666666667 0.07637626158259919
# adam 93.10666666666667 0.1844812546936226
# adabelief 95.28666666666668 0.19553345834750496
# adamp 95.18333333333334 0.11590225767142681
# adabound 94.83333333333333 0.13051181300301531
# amsgrad 93.76 0.10816653826391588
# rmsprop 93.06333333333333 0.12013880860627163
# sgd 94.61333333333334 0.2802379940931194

# %% [markdown]
# ### **DenseNet121**

# %%
names = {'adam':['densenet-adam-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'densenet-adam-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'densenet-adam-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
         ],
         'amsgrad':['densenet-amsgrad-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'densenet-amsgrad-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'densenet-amsgrad-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                                             
         ],
         'rmsprop':['densenet-rmsprop-seed111-lr0.001-wdecay0.0005-run0-resetFalse',
                    'densenet-rmsprop-seed222-lr0.001-wdecay0.0005-run0-resetFalse',
                    'densenet-rmsprop-seed333-lr0.001-wdecay0.0005-run0-resetFalse',                          
         ],
         'theopoula$^\dagger$':['densenet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'densenet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'densenet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                   
         ],
         'theopoula$^*$':['densenet-theopoula-seed111-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'densenet-theopoula-seed222-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'densenet-theopoula-seed333-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                   
         ],
         'sgd':['densenet-sgd-seed111-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'densenet-sgd-seed222-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'densenet-sgd-seed333-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
         ],
         'adabound':['densenet-adabound-seed111-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'densenet-adabound-seed222-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'densenet-adabound-seed333-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
         ],
         'adabelief':['densenet-adabelief-seed111-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'densenet-adabelief-seed222-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'densenet-adabelief-seed333-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',             
                     ],
         'adamp':['densenet-adamp-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                  
                      'densenet-adamp-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                      'densenet-adamp-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',             
                     ],
         'tuslac': ['densenet-tuslac-seed111-lr0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse'],
        }
labels = ['TheoPouLa$^\dagger$', 
          'TheoPouLa$^*$', 
          #'tuslac',
          'Adam',          
          'AdaBelief',
          'AdamP',
          'AdaBound',
          'Amsgrad',          
          'Rmsprop',          
          'SGD',            
         ]
model = 'densenet121'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (88,96)) 
get_best_acc(names, curve_type='test', model=model, labels=labels)
# Out:
# theopoula$^\dagger$ 95.66000000000001 0.0655743852430178
# theopoula$^*$ 95.59333333333332 0.06658328118479527
# adam 93.20666666666666 0.23965252624024452
# adabelief 95.58333333333333 0.0945163125250494
# adamp 95.17 0.07937253933194072
# adabound 95.05333333333333 0.17616280348964777
# amsgrad 93.74 0.23643180835073732
# rmsprop 92.88999999999999 0.3104834939252028
# sgd 94.45666666666666 0.15947831618540995

# %% [markdown]
# ##  CIFAR100

# %% [markdown]
# ## VGG11

# %%
names = {'adam':['cifar100-vgg_bn-adam-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'cifar100-vgg_bn-adam-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'cifar100-vgg_bn-adam-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
          ],
         'amsgrad':['cifar100-vgg_bn-amsgrad-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'cifar100-vgg_bn-amsgrad-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'cifar100-vgg_bn-amsgrad-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                                
             
         ],
         'rmsprop':['cifar100-vgg_bn-rmsprop-seed111-lr0.001-wdecay0.0005-run0-resetFalse',
                    'cifar100-vgg_bn-rmsprop-seed222-lr0.001-wdecay0.0005-run0-resetFalse',
                    'cifar100-vgg_bn-rmsprop-seed333-lr0.001-wdecay0.0005-run0-resetFalse', 
                    
             
         ],
         'theopoula$^\dagger$':['cifar100-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
             
         ],
        'theopoula$^*$':['cifar100-vgg_bn-theopoula-seed111-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                              'cifar100-vgg_bn-theopoula-seed222-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                              'cifar100-vgg_bn-theopoula-seed333-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse', 
             
         ],
         'sgd':['cifar100-vgg_bn-sgd-seed111-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'cifar100-vgg_bn-sgd-seed222-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'cifar100-vgg_bn-sgd-seed333-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
         ],
         'adabound':['cifar100-vgg_bn-adabound-seed111-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'cifar100-vgg_bn-adabound-seed222-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'cifar100-vgg_bn-adabound-seed333-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
         ],
         'tuslac': ['cifar100-vgg_bn-tuslac-seed111-lr0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse'],
        'adabelief':['cifar100-vgg_bn-adabelief-seed111-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'cifar100-vgg_bn-adabelief-seed222-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'cifar100-vgg_bn-adabelief-seed333-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',             
                     ],
         'adamp':['cifar100-vgg_bn-adamp-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                  
                      'cifar100-vgg_bn-adamp-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                      'cifar100-vgg_bn-adamp-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',             
                     ],
        }
labels = ['TheoPouLa$^\dagger$', 
          'TheoPouLa$^*$', 
          'Adam',
          'AdaBelief',
          'AdamP',          
          'AdaBound',
          'Amsgrad',
          'Rmsprop',                    
          'SGD',               
         ]
model = 'vgg11'
dataset = 'cifar100'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (45, 71), dataset=dataset) 
get_best_acc(names, curve_type='test', model=model, labels=labels, dataset=dataset)
# Out:
# theopoula$^\dagger$ 70.30666666666667 0.11718930554164442
# theopoula$^*$ 70.24 0.22715633383201142
# adam 67.30333333333334 0.13650396819628682
# adabelief 69.50333333333333 0.11060440015358045
# adamp 69.41333333333334 0.2967041174863169
# adabound 68.61 0.3119294792096439
# amsgrad 67.71333333333332 0.29143323992525716
# rmsprop 65.45333333333333 0.3942503434790303
# sgd 67.77666666666667 0.3202082655606091

# %% [markdown]
# # Renet34

# %%
names = {'adam':['cifar100-resnet-adam-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'cifar100-resnet-adam-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'cifar100-resnet-adam-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
          ],
         'amsgrad':['cifar100-resnet-amsgrad-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'cifar100-resnet-amsgrad-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'cifar100-resnet-amsgrad-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                                
             
         ],
         'rmsprop':['cifar100-resnet-rmsprop-seed111-lr0.001-wdecay0.0005-run0-resetFalse',
                    'cifar100-resnet-rmsprop-seed222-lr0.001-wdecay0.0005-run0-resetFalse',
                    'cifar100-resnet-rmsprop-seed333-lr0.001-wdecay0.0005-run0-resetFalse', 
                    
             
         ],
         'theopoula$^*$':['cifar100-resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'cifar100-resnet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'cifar100-resnet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
             
         ],
        'theopoula$^\dagger$':['cifar100-resnet-theopoula-seed111-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',
                     'cifar100-resnet-theopoula-seed222-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',
                     'cifar100-resnet-theopoula-seed333-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',                                
         ],        
         
         'sgd':['cifar100-resnet-sgd-seed111-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'cifar100-resnet-sgd-seed222-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'cifar100-resnet-sgd-seed333-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
         ],
         'adabound':['cifar100-resnet-adabound-seed111-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'cifar100-resnet-adabound-seed222-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'cifar100-resnet-adabound-seed333-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
         ],
         'adabelief':['cifar100-resnet-adabelief-seed111-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'cifar100-resnet-adabelief-seed222-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'cifar100-resnet-adabelief-seed333-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',             
                     ],
         'adamp':['cifar100-resnet-adamp-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                  
                      'cifar100-resnet-adamp-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                      'cifar100-resnet-adamp-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',             
                     ],
         'tuslac': ['cifar100-resnet-tuslac-seed111-lr0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse'],
         
        }
labels = ['TheoPouLa$^\dagger$', 
          'TheoPouLa$^*$',
          'Adam',   
          'AdaBelief',
         'AdamP',          
          'AdaBound',
          'Amsgrad',          
          'Rmsprop',                    
          'SGD',         
         ]
model = 'resnet34'
dataset = 'cifar100'

agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (60, 78), dataset=dataset) 
get_best_acc(names, curve_type='test', model=model, labels=labels, dataset=dataset)
# Out:
# theopoula$^\dagger$ 77.60000000000001 0.20880613017821031
# theopoula$^*$ 76.88333333333334 0.5359415391004244
# adam 73.02 0.23065125189341315
# adabelief 77.32666666666667 0.17156145643277246
# adamp 76.14 0.3469870314579455
# adabound 76.27333333333333 0.255799400572665
# amsgrad 73.50666666666666 0.6916887546673947
# rmsprop 71.78666666666668 0.2872861523522079
# sgd 77.15666666666665 0.2138535324312754

# %% [markdown]
# # Densenet121

# %%
names = {'adam':['cifar100-densenet-adam-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'cifar100-densenet-adam-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                 'cifar100-densenet-adam-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
          ],
         'amsgrad':['cifar100-densenet-amsgrad-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'cifar100-densenet-amsgrad-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                    'cifar100-densenet-amsgrad-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                                
             
         ],
         'rmsprop':['cifar100-densenet-rmsprop-seed111-lr0.001-wdecay0.0005-run0-resetFalse',
                    'cifar100-densenet-rmsprop-seed222-lr0.001-wdecay0.0005-run0-resetFalse',
                    'cifar100-densenet-rmsprop-seed333-lr0.001-wdecay0.0005-run0-resetFalse',             
             
         ],
         'theopoula$^\dagger$':['cifar100-densenet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'cifar100-densenet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'cifar100-densenet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
             
         ],
        'theopoula$^*$':['cifar100-densenet-theopoula-seed111-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                              'cifar100-densenet-theopoula-seed222-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                              'cifar100-densenet-theopoula-seed333-lr0.05-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse', 
             
         ],
         'sgd':['cifar100-densenet-sgd-seed111-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'cifar100-densenet-sgd-seed222-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
                'cifar100-densenet-sgd-seed333-lr0.1-momentum0.9-wdecay0.0005-run0-resetFalse',
         ],
         'adabound':['cifar100-densenet-adabound-seed111-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'cifar100-densenet-adabound-seed222-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
                     'cifar100-densenet-adabound-seed333-lr0.001-betas0.9-0.999-final_lr0.1-gamma0.001-wdecay0.0005-run0-resetFalse',
         ],
         'adabelief':['cifar100-densenet-adabelief-seed111-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'cifar100-densenet-adabelief-seed222-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',
                      'cifar100-densenet-adabelief-seed333-lr0.001-betas0.9-0.999-eps1e-08-wdecay0.0005-run0-resetFalse',             
                     ],
         'adamp':['cifar100-densenet-adamp-seed111-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',                  
                      'cifar100-densenet-adamp-seed222-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',
                      'cifar100-densenet-adamp-seed333-lr0.001-betas0.9-0.999-wdecay0.0005-eps1e-08-run0-resetFalse',             
                     ],
        }
labels = ['TheoPouLa$^\dagger$', 
          'TheoPouLa$^*$',
          'Adam',
          'AdaBelief',          
          'AdamP',          
          'AdaBound',
          'Amsgrad',          
          'Rmsprop',                    
          'SGD',               
         ]
model = 'densenet121'
dataset = 'cifar100'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (60, 80), dataset=dataset) 
get_best_acc(names, curve_type='test', model=model, labels=labels, dataset=dataset)
# Out:
# theopoula$^\dagger$ 79.90333333333334 0.1331665623695859
# theopoula$^*$ 78.75999999999999 0.26851443164194894
# adam 74.03333333333335 0.33381631675718304
# adabelief 79.12 0.38157568056678054
# adamp 77.57666666666667 0.0907377172587754
# adabound 77.55666666666667 0.12013880860627202
# amsgrad 74.50333333333334 0.4158525379666857
# rmsprop 71.75 0.6317436188834789
# sgd 78.95333333333333 0.3121431295629191

# %% [markdown]
# # \BETA

# %%
names = {'theopoula1e12':['cifar100-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
             
         ],
         'theopoula1e10':['cifar100-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',                                   
         ],
        'theopoula1e8':['cifar100-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',                                   
         ],
         'theopoula1e6':['cifar100-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',                                   
         ],
         'theopoula1e4':['cifar100-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',                                   
         ],
         'theopoula1e0':['cifar100-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',
                     'cifar100-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',                                   
         ],
        }
labels = ['theopoula1e12', 
          'theopoula1e10', 
          'theopoula1e8', 
          'theopoula1e6',           
          'theopoula1e4',           
          'theopoula1e0',    
         ]
model = 'vgg11'
dataset = 'cifar100'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (45, 71), dataset=dataset) 
get_best_acc(names, curve_type='test', model=model, labels=labels, dataset=dataset)
# Out:
# theopoula1e12 70.30666666666667 0.11718930554164442
# theopoula1e10 70.16333333333334 0.11015141094572163
# theopoula1e8 70.28333333333333 0.12423096769055947
# theopoula1e6 70.0 0.3439476704383982
# theopoula1e4 20.69333333333333 0.718215380880509
# theopoula1e0 70.39 0.18357559750685262

# %%
names = {'theopoula1e12':['cifar100-resnet-theopoula-seed111-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'cifar100-resnet-theopoula-seed222-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'cifar100-resnet-theopoula-seed333-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
             
         ],
        'theopoula1e10':['cifar100-resnet-theopoula-seed111-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',
                     'cifar100-resnet-theopoula-seed222-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',
                     'cifar100-resnet-theopoula-seed333-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',                                
         ],
        'theopoula1e8':['cifar100-resnet-theopoula-seed111-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',
                     'cifar100-resnet-theopoula-seed222-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',
                     'cifar100-resnet-theopoula-seed333-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',                                
         ],
         'theopoula1e6':['cifar100-resnet-theopoula-seed111-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',
                     'cifar100-resnet-theopoula-seed222-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',
                     'cifar100-resnet-theopoula-seed333-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',                                
         ],
         'theopoula1e4':['cifar100-resnet-theopoula-seed111-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',
                     'cifar100-resnet-theopoula-seed222-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',
                     'cifar100-resnet-theopoula-seed333-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',                                
         ],
         'theopoula1e0':['cifar100-resnet-theopoula-seed111-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',
                     'cifar100-resnet-theopoula-seed222-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',
                     'cifar100-resnet-theopoula-seed333-lr0.05-eps0.01-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',                                
         ],
        }
labels = ['theopoula1e12', 
          'theopoula1e10', 
          'theopoula1e8', 
          'theopoula1e6',           
          'theopoula1e4',           
          'theopoula1e0',           
         ]
model = 'resnet34'
dataset = 'cifar100'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (45, 78), dataset=dataset) 
get_best_acc(names, curve_type='test', model=model, labels=labels, dataset=dataset)
# Out:
# theopoula1e12 77.53333333333333 0.14364307617609992
# theopoula1e10 77.60000000000001 0.20880613017821031
# theopoula1e8 77.4 0.036055512754642575
# theopoula1e6 77.22 0.2913760456866726
# theopoula1e4 63.580000000000005 0.10392304845413247
# theopoula1e0 77.35666666666667 0.09018499505646146

# %%
names = {'theopoula1e12':['vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
                     'vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                     'vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
             
         ],
         'theopoula1e10':['cifar10-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',                                   
         ],
        'theopoula1e8':['cifar10-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',                                   
         ],
         'theopoula1e6':['cifar10-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',                                   
         ],
         'theopoula1e4':['cifar10-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',                                   
         ],
         'theopoula1e0':['cifar10-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',
                     'cifar10-vgg_bn-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',                                   
         ],
        }
labels = ['theopoula1e12', 
          'theopoula1e10', 
          'theopoula1e8', 
          'theopoula1e6',           
          'theopoula1e4',           
          'theopoula1e0',           
         ]
model = 'vgg11'
dataset = 'cifar10'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (64, 92.5), dataset=dataset) 
get_best_acc(names, curve_type='test', model=model, labels=labels, dataset=dataset)
# Out:
# theopoula1e12 92.10333333333334 0.023094010767580435
# theopoula1e10 92.29333333333334 0.12013880860626472
# theopoula1e8 92.30666666666667 0.055075705472860816
# theopoula1e6 91.53333333333335 0.14189197769195291
# theopoula1e4 73.10333333333334 0.40722639076235195
# theopoula1e0 92.21666666666668 0.04509249752823048

# %%
names = {'theopoula1e12':['resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                
                      'resnet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',
                      'resnet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                            
         ],        
         'theopoula1e10':['cifar10-resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',                      
                          'cifar10-resnet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',                      
                        'cifar10-resnet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+10-resetFalse',                                   
         ],        
         'theopoula1e8':['cifar10-resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',                      
                          'cifar10-resnet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',                      
                        'cifar10-resnet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+08-resetFalse',                                   
         ],        
         'theopoula1e6':['cifar10-resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',                      
                          'cifar10-resnet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',                      
                        'cifar10-resnet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+06-resetFalse',                                   
         ],        
         'theopoula1e4':['cifar10-resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',                      
                          'cifar10-resnet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',                      
                        'cifar10-resnet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+04-resetFalse',     
         ],        
         'theopoula1e0':['cifar10-resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',                      
                          'cifar10-resnet-theopoula-seed222-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',                      
                        'cifar10-resnet-theopoula-seed333-lr0.1-eps0.1-wdecay0.0005-run0-lrgamma0.1-epsgamma1-beta 1.0e+00-resetFalse',     
         ],        
        }
labels = ['theopoula1e12', 
          'theopoula1e10', 
          'theopoula1e8', 
          'theopoula1e6', 
          'theopoula1e4',           
          'theopoula1e0',           
         ]
model = 'resnet34'
dataset = 'cifar10'
agg_plot(names, curve_type='test', model=model, labels=labels, ylim = (88,96), dataset=dataset) 
get_best_acc(names, curve_type='test', model=model, labels=labels)
# Out:
# theopoula1e12 95.42999999999999 0.09539392014169346
# theopoula1e10 95.34333333333335 0.14153915830374625
# theopoula1e8 95.42 0.11789826122551722
# theopoula1e6 94.67 0.14525839046333555
# theopoula1e4 80.84000000000002 0.2645751311064575
# theopoula1e0 95.53666666666668 0.12423096769056766

# %% [markdown]
# # **r=10 high regularization**

# %%
def get_agg_data(names, curve_type='train'):
    folder_path = './logs/regularization/'
    paths = [os.path.join(folder_path, name) for name in names]  
    curves = {name: torch.load(fp) for name, fp in zip(names, paths)}#get_data(names[opt])  
    df_agg = pd.DataFrame({ key : value[curve_type +'_acc'] for key, value in curves.items()})
    return df_agg

def agg_plot(names, curve_type='train', labels = None, ylim=(80,101), loc = 'upper left', figsize=(10,8)):
    plt.figure(figsize=figsize)
    plt.ylim(ylim)
    opts = [label.lower() for label in labels]
  
    for opt, label in zip(opts, labels):
   
        df_agg = get_agg_data(names[opt], curve_type)
    
        
    
        acc = np.array(df_agg.mean(axis=1))
        std = np.array(df_agg.std(axis=1))    
        x = range(1, len(acc)+1)
        if 'theopoula' in label.lower():
            plt.plot(x, acc, '-', label=label, linewidth=2)
        else: 
            plt.plot(x, acc, '--', label=label, linewidth=2)
        plt.fill_between(x, acc-std, acc+std, alpha=0.15)
  
    plt.legend(fontsize=25, loc=loc)
    plt.grid()
    plt.title('{} ACCURACY'.format(curve_type.upper()))
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.xticks(fontsize =20)
    plt.yticks(fontsize =20)
    plt.tight_layout()
    plt.show()

def get_best_acc(names, curve_type='train', labels = None):  
    opts = [label.lower() for label in labels]
  
    for opt, label in zip(opts, labels):
        df_agg = get_agg_data(names[opt], curve_type)
        print(opt, df_agg.max(axis=0).mean(), df_agg.max(axis=0).std())

# %%
names = {'vgg_10':['cifar10-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                                      
         ],        
         'resnet_10':['cifar10-resnet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                                
         ],        
         'densenet_10':['cifar10-densenet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
         ],        
         'vgg_100':['cifar100-vgg_bn-theopoula-seed111-lr0.1-eps0.1-wdecay0.0-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                                      
         ],        
         'resnet_100':['cifar100-resnet-theopoula-seed111-lr0.05-eps0.01-wdecay0.0-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                                                
         ],        
         'densenet_100':['cifar100-densenet-theopoula-seed111-lr0.1-eps0.1-wdecay0.0-run0-lrgamma0.1-epsgamma1-beta 1.0e+12-resetFalse',                      
         ],        
        }
labels = ['vgg_10',          
          'resnet_10',
          'densenet_10',
          'vgg_100',          
          'resnet_100',
          'densenet_100',
         ]
agg_plot(names, curve_type='test', labels=labels, ylim = (88,96)) 
get_best_acc(names, curve_type='test', labels=labels)
# Out:
# vgg_10 92.2 nan
# resnet_10 95.38 nan
# densenet_10 95.69 nan
# vgg_100 70.07 nan
# resnet_100 77.78 nan
# densenet_100 80.47 nan
